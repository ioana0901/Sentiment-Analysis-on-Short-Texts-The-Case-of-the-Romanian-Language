# %%
import import_ipynb
from FunctionsList import *
import pandas as pd
import numpy as np
import random
import gensim
import joblib

from tensorflow.keras.utils import to_categorical

from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras import regularizers, callbacks
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from keras.layers import Embedding, Flatten, Dense, LSTM, GRU, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Bidirectional, Dropout
from keras.regularizers import l2
# Out:
# importing Jupyter notebook from FunctionsList.ipynb

# %%
#import data:
data = pd.read_csv('Data/CleanDataset.csv')
#sterge prima coloana
data = data.iloc[: , 1:]
data.head()
# Out:
#    label                                     review_content
# 0      2  telefon solid complex telefon trebui user medi...
# 1      0  samsung sfe aproxim zil trecut diferent sist a...
# 2      2  livr inceat zil vizav telefon multum greu foli...
# 3      0  pacat display sparg mic ating inlocu cost apro...
# 4      1  misc bin ok costat stel deoarec nu instal prog...

# %% [markdown]
# ### Impartirea setului de date

# %%
# imparte setul de date: 80% - 20% 
contents = data['review_content']
labels = data['label']
x_train, x_test, y_train, y_test = train_test_split(contents, labels, train_size=0.8, random_state=42)

# %% [markdown]
# ### Vectorizare

# %%
# Transformarea cuvintelor in float
tokenizer = Tokenizer(num_words = 9000) #maxim 9000 cele mai comune cuvinte

# crearea vocabularului
tokenizer.fit_on_texts(x_train)
# numarul de cuvinte unice
unique_words = tokenizer.word_index

# converteste textul in float pentru x
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

#sunt 15120 tokeni unici
print('%s unique tokens' % len(unique_words))
# Out:
# 15120 unique tokens

# %%
# identifica lungimea maxima a recenziilor
maxlen = 0
for rev_n in range(len(x_train)):
    n = len(x_train[rev_n])
    if n > maxlen:
        maxlen = n
print(maxlen)
# Out:
# 1115

# %%
# de vreme ce unele recenzii au o lungime mai mica decat lungimea maxima calculata mai sus (1115)
# - ele trebuie aduse la aceeasi lungime pentru a avea acelasi shape
# padding pentru ambele seturi
x_train = pad_sequences(x_train, maxlen=maxlen) #pad sequences so they have same length
x_test = pad_sequences(x_test, maxlen=maxlen)

print("x_train.shape:", x_train.shape)
print("x_test.shape :", x_test.shape)
# Out:
# x_train.shape: (12900, 1115)
# x_test.shape : (3225, 1115)

# %%
#one-hot encode labels
y_train = to_categorical(y_train, num_classes=3)
y_test = to_categorical(y_test, num_classes=3)
print("y_train.shape:", y_train.shape)
print("y_test.shape :", y_test.shape)
# Out:
# y_train.shape: (12900, 3)
# y_test.shape : (3225, 3)

# %% [markdown]
# ### Incarcarea  modelului pre-antrenat FastText

# %%
#import gdown
#url = 'https://drive.google.com/file/d/1DEVyeouTceHnFKSn72Mv_pELk_v2tG0o/view?usp=sharing'
#output = 'cc.ro.300.bin'
#gdown.download(url, output, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DEVyeouTceHnFKSn72Mv_pELk_v2tG0o
# To: /home/fsega/ioana.baghiut/project/cc.ro.300.bin
# 100%|██████████| 7.24G/7.24G [14:09<00:00, 8.52MB/s]
# 'cc.ro.300.bin'

# %%
import fasttext
#fasttext.util.download_model('ro', if_exists='ignore') 
ft = fasttext.load_model('cc.ro.300.bin')

# %%
dir(ft)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_labels',
#  '_words',
#  'f',
#  'get_dimension',
#  'get_input_matrix',
#  'get_input_vector',
#  'get_labels',
#  'get_line',
#  'get_output_matrix',
#  'get_sentence_vector',
#  'get_subword_id',
#  'get_subwords',
#  'get_word_id',
#  'get_word_vector',
#  'get_words',
#  'is_quantized',
#  'labels',
#  'predict',
#  'quantize',
#  'save_model',
#  'test',
#  'test_label',
#  'words']

# %%
# modelul are 300 de dimensiune -> fiecare cuvant are 300 dim si peste 18000 de cuvinte
# de vreme ce suntem interesati doar de cele 15120 cuvinte din setul de train -> cream matricea embedding de forma (15120+1, 300)
total_words = len(unique_words) + 1
skipped_words = 0 
l=[] #vezi skipped words daca exista
embedding_dim = 300
embedding_matrix = np.zeros((total_words, embedding_dim)) #forma matricei 

for word, i in tokenizer.word_index.items():
    if ft.__contains__(word):
        embedding_matrix[i] = ft.__getitem__(word)
    else:
        skipped_words = skipped_words + 1
        l.append(word)
        
print("Embedding Matrix Shape:", embedding_matrix.shape)
# Out:
# Embedding Matrix Shape: (15121, 300)

# %%
#Crearea stratului de embedding
embedding_layer = Embedding(total_words, 
                            embedding_dim,
                            weights = [embedding_matrix],
                            input_length = maxlen, 
                            trainable = False)

# %%
skipped_words
# Out:
# 6126

# %%
l
# Out:
# ['bater',
#  'iphon',
#  'huawe',
#  'gogl',
#  'achizition',
#  'functioneaz',
#  'updat',
#  'youtub',
#  'catev',
#  'dezamag',
#  'jumat',
#  'xiaom',
#  'concluz',
#  'parer',
#  'apelur',
#  'incalzest',
#  'luminoz',
#  'asteptar',
#  'impec',
#  'optiun',
#  'wif',
#  'debloc',
#  'whatsap',
#  'minusur',
#  'upgrad',
#  'amoled',
#  'convorbir',
#  'noki',
#  'obisnu',
#  'bluetoth',
#  'softw',
#  'butoan',
#  'recunoast',
#  'difuzoar',
#  'intampl',
#  'resigil',
#  'pretent',
#  'snapdragon',
#  'gasest',
#  'scren',
#  'zgarietur',
#  'impresion',
#  'comenz',
#  'stabiliz',
#  'varst',
#  'enerv',
#  'plusur',
#  'redm',
#  'primest',
#  'instagr',
#  'devic',
#  'interf',
#  'exynos',
#  'imbunatat',
#  'hardw',
#  'zgar',
#  'claritat',
#  'pubg',
#  'deocamd',
#  'charg',
#  'degeab',
#  'filmar',
#  'dorest',
#  'inlocu',
#  'senzat',
#  'dezactiv',
#  'findc',
#  'cateod',
#  'incalz',
#  'neapar',
#  'conexiun',
#  'aiur',
#  'lipsest',
#  'alview',
#  'urech',
#  'pozition',
#  'privest',
#  'caracterist',
#  'intuner',
#  'irepros',
#  'recenz',
#  'showrom',
#  'actualizar',
#  'focaliz',
#  'preinstal',
#  'inregistr',
#  'obisnuiest',
#  'nemultum',
#  'bixby',
#  'precomand',
#  'rateur',
#  'videoclipur',
#  'intaln',
#  'caldur',
#  'gramad',
#  'convorb',
#  'greo',
#  'mediocr',
#  'pornest',
#  'personaliz',
#  'intarzier',
#  'motorol',
#  'fluiditat',
#  'oprest',
#  'customiz',
#  'debloch',
#  'justif',
#  'pretur',
#  'cazatur',
#  'greseal',
#  'gestur',
#  'felicitar',
#  'soner',
#  'modur',
#  'pastr',
#  'intunec',
#  'sacadeaz',
#  'sacad',
#  'clipur',
#  'ilumin',
#  'platest',
#  'antutu',
#  'incercar',
#  'citest',
#  'ergonom',
#  'intruc',
#  'reusest',
#  'dezinstal',
#  'soarel',
#  'touchscren',
#  'apgalery',
#  'execr',
#  'imbunatatir',
#  'afiseaz',
#  'midrang',
#  'brandur',
#  'deasemen',
#  'coltur',
#  'dezamagest',
#  'incarcar',
#  'promot',
#  'nuant',
#  'superl',
#  'redar',
#  'socur',
#  'chinezar',
#  'zenfon',
#  'batery',
#  'bloatw',
#  'extraordin',
#  'neastept',
#  'feling',
#  'reviewur',
#  'usurint',
#  'nimer',
#  'vizib',
#  'xper',
#  'reactioneaz',
#  'depasest',
#  'meniur',
#  'inafar',
#  'promptitudin',
#  'calibr',
#  'reporn',
#  'ecosist',
#  'ultrawid',
#  'bugur',
#  'mailur',
#  'intreruper',
#  'acomod',
#  'intotdeaun',
#  'amandou',
#  'gcam',
#  'nasp',
#  'gandest',
#  'incalzeasc',
#  'greoai',
#  'cunostint',
#  'unghiur',
#  'procesoar',
#  'multim',
#  'bijuter',
#  'easybox',
#  'qualcom',
#  'tinet',
#  'compenseaz',
#  'intoarc',
#  'inutiliz',
#  'vanz',
#  'updateur',
#  'rular',
#  'credet',
#  'potrivest',
#  'cheit',
#  'lagur',
#  'rotunj',
#  'swip',
#  'depanero',
#  'remed',
#  'tonur',
#  'perech',
#  'totod',
#  'dezact',
#  'fedback',
#  'preferint',
#  'smoth',
#  'enerveaz',
#  'obos',
#  'deconect',
#  'straluc',
#  'trezest',
#  'stelut',
#  'dezlip',
#  'forumur',
#  'intrebar',
#  'vitoar',
#  'obisn',
#  'gandur',
#  'supraincalz',
#  'tiktok',
#  'liniut',
#  'retel',
#  'insesiz',
#  'citir',
#  'vanzat',
#  'featur',
#  'multimed',
#  'neajunsur',
#  'sambat',
#  'necl',
#  'ihunt',
#  'gustur',
#  'fortnit',
#  'inaltim',
#  'aleget',
#  'kirin',
#  'forj',
#  'inchiz',
#  'vowif',
#  'apkpur',
#  'caramid',
#  'subtir',
#  'pregat',
#  'lipsur',
#  'incetin',
#  'supraincalzest',
#  'simur',
#  'distorsioneaz',
#  'doved',
#  'vanced',
#  'cautar',
#  'razn',
#  'panoram',
#  'sperant',
#  'acidental',
#  'miscar',
#  'instructiun',
#  'competit',
#  'nemaipomen',
#  'faceid',
#  'aptoid',
#  'racir',
#  'hav',
#  'navigh',
#  'teoret',
#  'sacadar',
#  'yaho',
#  'sugest',
#  'sedg',
#  'bratar',
#  'whatsup',
#  'cunoast',
#  'invet',
#  'ufs',
#  'incompar',
#  'incadr',
#  'restarteaz',
#  'doubl',
#  'inacept',
#  'buzun',
#  'neferic',
#  'spalac',
#  'oprir',
#  'sameday',
#  'limitar',
#  'nenumar',
#  'recunost',
#  'indeman',
#  'pastreaz',
#  'perspect',
#  'atinger',
#  'mediatek',
#  'niman',
#  'pacal',
#  'esim',
#  'storag',
#  'filtr',
#  'trecet',
#  'iesir',
#  'asteapt',
#  'videour',
#  'incorpor',
#  'palar',
#  'adecv',
#  'micsor',
#  'downgrad',
#  'leic',
#  'distorsion',
#  'adaptoar',
#  'serioz',
#  'costur',
#  'oscil',
#  'bineven',
#  'oneu',
#  'dinaint',
#  'superamoled',
#  'alteor',
#  'dezamageasc',
#  'vibr',
#  'securiz',
#  'mentiun',
#  'nicaier',
#  'qhd',
#  'flagshipur',
#  'moreaps',
#  'oarec',
#  'slotur',
#  'zbarnai',
#  'vremur',
#  'compatib',
#  'repornest',
#  'butucan',
#  'performanc',
#  'defectiun',
#  'fabul',
#  'preaplic',
#  'intarz',
#  'scurtatur',
#  'indragost',
#  'merget',
#  'frumuset',
#  'infund',
#  'vanzar',
#  'proceseaz',
#  'aleat',
#  'outlok',
#  'ingreuneaz',
#  'splus',
#  'trebuiasc',
#  'reseteaz',
#  'ingheat',
#  'fierbint',
#  'urmarest',
#  'picatur',
#  'dezactiveaz',
#  'iph',
#  'favoar',
#  'gsmaren',
#  'intreab',
#  'fontur',
#  'celorlalt',
#  'invech',
#  'apertur',
#  'multumest',
#  'microusb',
#  'fulhd',
#  'indeplinest',
#  'lamur',
#  'fotografier',
#  'configurar',
#  'operatiun',
#  'protectoar',
#  'detas',
#  'regas',
#  'waterprof',
#  'marest',
#  'criter',
#  'quickmob',
#  'ingroz',
#  'oricar',
#  'incredib',
#  'corning',
#  'achiziton',
#  'screnshot',
#  'wqhd',
#  'precomenz',
#  'galag',
#  'interactiun',
#  'suprasatur',
#  'nejustific',
#  'noutat',
#  'inregistreaz',
#  'inteleget',
#  'inadmis',
#  'obisnuint',
#  'kaios',
#  'midl',
#  'chestiun',
#  'impartas',
#  'desigil',
#  'cardur',
#  'perfom',
#  'firmw',
#  'walpaper',
#  'sfatur',
#  'impatim',
#  'uhd',
#  'nemultumest',
#  'remedier',
#  'achizion',
#  'cuiv',
#  'incadreaz',
#  'fetit',
#  'decup',
#  'pandem',
#  'instantan',
#  'naib',
#  'prestabil',
#  'deseor',
#  'distorsiun',
#  'reinstal',
#  'calum',
#  'softur',
#  'licent',
#  'ulefon',
#  'imbunatatest',
#  'focuseaz',
#  'indepart',
#  'clasrom',
#  'raspunz',
#  'pocophon',
#  'felic',
#  'watsap',
#  'incoac',
#  'gspac',
#  'setings',
#  'rareor',
#  'huawey',
#  'maric',
#  'sarbat',
#  'bestbuy',
#  'impotr',
#  'multitudin',
#  'artif',
#  'inact',
#  'problemat',
#  'palpai',
#  'seteaz',
#  'voic',
#  'brightnes',
#  'extens',
#  'densitat',
#  'obosest',
#  'suprafet',
#  'tasteaz',
#  'compromisur',
#  'buhnic',
#  'imperech',
#  'apstor',
#  'irelev',
#  'notit',
#  'fisur',
#  'aprecier',
#  'cumparar',
#  'landscap',
#  'chinezest',
#  'usag',
#  'experienc',
#  'acentu',
#  'lucioas',
#  'ingrijor',
#  'kiler',
#  'fascin',
#  'vrajeal',
#  'latim',
#  'spigen',
#  'sectiun',
#  'dxomark',
#  'formid',
#  'capteaz',
#  'prindet',
#  'nucl',
#  'cader',
#  'tipl',
#  'magnif',
#  'randur',
#  'nepretent',
#  'inregistrar',
#  'alocur',
#  'functiun',
#  'indoai',
#  'mecanist',
#  'sped',
#  'scriet',
#  'suprinz',
#  'inlocuiest',
#  'explod',
#  'regasest',
#  'ingreun',
#  'playstor',
#  'cumparatur',
#  'cinemat',
#  'familiariz',
#  'rotir',
#  'nemisc',
#  'indoieln',
#  'indoial',
#  'nightmod',
#  'updatur',
#  'samsungur',
#  'gresel',
#  'customizar',
#  'touchwiz',
#  'macbok',
#  'lipest',
#  'impachet',
#  'handsfr',
#  'orib',
#  'incomodeaz',
#  'apasar',
#  'felur',
#  'neplacer',
#  'traget',
#  'sensib',
#  'reorient',
#  'emailur',
#  'pietr',
#  'soacr',
#  'profunzim',
#  'simplitat',
#  'acesib',
#  'kfps',
#  'dimpotr',
#  'migr',
#  'outdor',
#  'auror',
#  'purpl',
#  'razgand',
#  'microfoan',
#  'incind',
#  'genshin',
#  'xiom',
#  'wak',
#  'uimest',
#  'egaliz',
#  'whatap',
#  'swiftkey',
#  'perfectiun',
#  'zicet',
#  'nimerest',
#  'scoatet',
#  'domnisoar',
#  'flir',
#  'cireas',
#  'sultr',
#  'retiner',
#  'vigafon',
#  'hib',
#  'iros',
#  'desavars',
#  'nostalg',
#  'headphon',
#  'ramanet',
#  'widgetur',
#  'incheg',
#  'varfur',
#  'candv',
#  'reprosur',
#  'moftur',
#  'satisfact',
#  'funtioneaz',
#  'inteleag',
#  'nesimt',
#  'lovest',
#  'gimick',
#  'achizitionar',
#  'covid',
#  'aseaz',
#  'crapatur',
#  'magsaf',
#  'glovo',
#  'instalar',
#  'caliat',
#  'vietn',
#  'duals',
#  'pierdet',
#  'gekbench',
#  'spen',
#  'standof',
#  'nemultumir',
#  'dific',
#  'plictisest',
#  'verz',
#  'cach',
#  'neinspir',
#  'prezentar',
#  'gaseasc',
#  'exin',
#  'impied',
#  'cheil',
#  'onedr',
#  'invid',
#  'forteaz',
#  'vdf',
#  'forc',
#  'restartur',
#  'casut',
#  'aptx',
#  'telegr',
#  'sincronizeaz',
#  'inexplic',
#  'inceap',
#  'contraz',
#  'scroling',
#  'incompat',
#  'nesemnific',
#  'sonoriz',
#  'plateasc',
#  'remediaz',
#  'inestet',
#  'ciclur',
#  'ericson',
#  'scapar',
#  'saptamin',
#  'tavit',
#  'trant',
#  'nanos',
#  'matepro',
#  'luas',
#  'resoft',
#  'infrumuset',
#  'treim',
#  'incuraj',
#  'zeis',
#  'sumeden',
#  'invarst',
#  'garmin',
#  'tampen',
#  'portiun',
#  'sageat',
#  'trimitet',
#  'coler',
#  'anevoi',
#  'inceat',
#  'blureaz',
#  'defectu',
#  'navigheaz',
#  'rinich',
#  'indispens',
#  'unicred',
#  'inbunatat',
#  'acust',
#  'ghic',
#  'touchid',
#  'imbatran',
#  'biometr',
#  'crashur',
#  'spedtest',
#  'debif',
#  'fulscren',
#  'atip',
#  'stabilizar',
#  'blotw',
#  'caramiz',
#  'pasioneaz',
#  'investest',
#  'dezlipest',
#  'imperfectiun',
#  'strun',
#  'ditam',
#  'dubioas',
#  'taskur',
#  'selfiur',
#  'inebun',
#  'incetos',
#  'raritat',
#  'surfac',
#  'pliaz',
#  'tefon',
#  'inlocuiasc',
#  'acuratet',
#  'andur',
#  'indeplin',
#  'otg',
#  'slep',
#  'murdarest',
#  'convinget',
#  'mentioneaz',
#  'redit',
#  'trecer',
#  'ruged',
#  'btpay',
#  'planger',
#  'achzition',
#  'cubot',
#  'rebot',
#  'maxcom',
#  'reimprospat',
#  'sharpnes',
#  'bluethot',
#  'fotografiaz',
#  'quickcharg',
#  'zgarai',
#  'recomandar',
#  'airpods',
#  'defavoar',
#  'useles',
#  'indrazn',
#  'flyme',
#  'granul',
#  'huwe',
#  'puner',
#  'acesoriu',
#  'precizar',
#  'miroring',
#  'inghesu',
#  'smartphonur',
#  'achizitioneaz',
#  'surubur',
#  'detinet',
#  'scopur',
#  'comparandu',
#  'implin',
#  'ingalben',
#  'aeris',
#  'grabest',
#  'initializ',
#  'deopart',
#  'crangas',
#  'dongl',
#  'revanz',
#  'verificar',
#  'camas',
#  'stocur',
#  'blackbery',
#  'overheating',
#  'incetinest',
#  'indat',
#  'htps',
#  'expedier',
#  'siteur',
#  'suround',
#  'nasoal',
#  'obsed',
#  'octacor',
#  'botlop',
#  'masoar',
#  'solicitar',
#  'tandar',
#  'marir',
#  'deterioreaz',
#  'achition',
#  'rigoar',
#  'tabar',
#  'raportandu',
#  'andoid',
#  'wats',
#  'bleding',
#  'helo',
#  'rosiat',
#  'neutiliz',
#  'strainat',
#  'dispay',
#  'scaneaz',
#  'hmin',
#  'inevit',
#  'obses',
#  'neintuit',
#  'adez',
#  'scartai',
#  'deobice',
#  'scenar',
#  'predefin',
#  'citev',
#  'walet',
#  'economisest',
#  'cronometr',
#  'shuter',
#  'imbunatateasc',
#  'confection',
#  'cercur',
#  'sacrif',
#  'personalizar',
#  'stupoar',
#  'disparit',
#  'slid',
#  'smarphon',
#  'smartswitch',
#  'consecut',
#  'bifeaz',
#  'racest',
#  'telfon',
#  'snapy',
#  'fuctioneaz',
#  'xaom',
#  'influenteaz',
#  'postproces',
#  'flawles',
#  'raifeisen',
#  'inseal',
#  'chichit',
#  'supercharg',
#  'brichet',
#  'robustet',
#  'ringk',
#  'zangan',
#  'logar',
#  'ultiliz',
#  'permitet',
#  'supraexpun',
#  'watsup',
#  'sapataman',
#  'patet',
#  'emoj',
#  'chiuvet',
#  'raspunsur',
#  'eron',
#  'supraevalu',
#  'suprasolic',
#  'ciudaten',
#  'loter',
#  'inrol',
#  'cantarest',
#  'certificar',
#  'introducet',
#  'telecomenz',
#  'neschimb',
#  'incetinir',
#  'prisosint',
#  'conecting',
#  'stangac',
#  'marturis',
#  'overkil',
#  'batet',
#  'multumir',
#  'acubatery',
#  'mpixel',
#  'orif',
#  'franeaz',
#  'indiscut',
#  'senzoru',
#  'saracac',
#  'caling',
#  'gajai',
#  'intodeaun',
#  'obijnu',
#  'uag',
#  'utliz',
#  'altad',
#  'totdeaun',
#  'scutest',
#  'fractiun',
#  'androiz',
#  'sterget',
#  'tft',
#  'resetar',
#  'galax',
#  'tinandu',
#  'myphon',
#  'pocofon',
#  'promisiun',
#  'primavar',
#  'prety',
#  'promtitudin',
#  'actioneaz',
#  'nerefuz',
#  'mandr',
#  'papur',
#  'comentur',
#  'ajustar',
#  'intalnest',
#  'longev',
#  'benchmarkur',
#  'awesom',
#  'parar',
#  'descarcar',
#  'ingalbenest',
#  'reinregistr',
#  'incomfort',
#  'gadgetur',
#  'supraincalzeasc',
#  'neobt',
#  'reincarcar',
#  'vostr',
#  'clarif',
#  'declanseaz',
#  'oflin',
#  'declans',
#  'lockscren',
#  'circumst',
#  'mijloac',
#  'esd',
#  'nepotriv',
#  'achiztion',
#  'glastic',
#  'walpapers',
#  'luandu',
#  'energet',
#  'autentif',
#  'nedetas',
#  'cals',
#  'nelimit',
#  'patest',
#  'semnaliz',
#  'botloader',
#  'codur',
#  'hotarast',
#  'neoptimiz',
#  'scaz',
#  'trebur',
#  'defecteaz',
#  'screntim',
#  'gasir',
#  'bixb',
#  'pregatest',
#  'ochiur',
#  'rotest',
#  'dreptungh',
#  'balar',
#  'reved',
#  'incapataneaz',
#  'conferint',
#  'dsfa',
#  'rautac',
#  'avandu',
#  'wek',
#  'taietur',
#  'nelamur',
#  'adreno',
#  'astui',
#  'ledur',
#  'petard',
#  'glosy',
#  'obisnuiasc',
#  'diming',
#  'volumin',
#  'deced',
#  'spet',
#  'discharging',
#  'disconecting',
#  'updad',
#  'utiz',
#  'catifel',
#  'choic',
#  'deblocar',
#  'hardcor',
#  'performeaz',
#  'poset',
#  'amintest',
#  'incar',
#  'postar',
#  'disabl',
#  'infoc',
#  'haidet',
#  'chipur',
#  'apropr',
#  'frustrar',
#  'traiasc',
#  'ducet',
#  'adob',
#  'ghicest',
#  'posesoar',
#  'bacter',
#  'comanz',
#  'fitbit',
#  'sfertur',
#  'mesinger',
#  'sezor',
#  'borset',
#  'reconecteaz',
#  'zenu',
#  'deosebest',
#  'fbk',
#  'tramv',
#  'concluzion',
#  'restartar',
#  'stearg',
#  'plasar',
#  'gafai',
#  'zvonur',
#  'gigab',
#  'lipic',
#  'nesper',
#  'neacept',
#  'scorur',
#  'intiln',
#  'panason',
#  'disip',
#  'tenteaz',
#  'fluctueaz',
#  'bloceaz',
#  'blury',
#  'anapod',
#  'vizav',
#  'virst',
#  'pitak',
#  'decupeaz',
#  'downsid',
#  'miror',
#  'meizu',
#  ...]

# %% [markdown]
# ## Crearea si antrenarea modelelor

# %% [markdown]
# ### LSTM

# %%
# definirea modelului-------------8------------------
lstm_model = Sequential()
lstm_model.add(embedding_layer)
lstm_model.add(LSTM(8))
lstm_model.add(Dense(3, activation = 'softmax'))

lstm_model.compile(optimizer='rmsprop',
                   loss='categorical_crossentropy',
                   metrics=['acc'])
history = lstm_model.fit(x_train, 
                         y_train,
                         epochs=10,
                         batch_size=64,
                         validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] -
# 172/172 [==============================] - 1770s 10s/step - loss: 0.7404 - acc: 0.6734 - val_loss: 0.7300 - val_acc: 0.6760
# Epoch 9/10
# 172/172 [==============================] - 1588s 9s/step - loss: 0.7583 - acc: 0.6661 - val_loss: 0.7403 - val_acc: 0.6615
# Epoch 10/10
# 172/172 [==============================] - 1613s 9s/step - loss: 0.7708 - acc: 0.6614 - val_loss: 0.7349 - val_acc: 0.6853

# %%
plot_graphs(history)

# %%
# definirea modelului-------------512------------------
lstm_model = Sequential()
lstm_model.add(embedding_layer)
lstm_model.add(LSTM(512))
lstm_model.add(Dense(3, activation = 'softmax'))

lstm_model.compile(optimizer='rmsprop',
                   loss='categorical_crossentropy',
                   metrics=['acc'])
history = lstm_model.fit(x_train, 
                         y_train,
                         epochs=10,
                         batch_size=64,
                         validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 478s 3s/step - loss: 0.9876 - acc: 0.5425 - val_loss: 0.9615 - val_acc: 0.5401
# Epoch 2/10
# 172/172 [==============================] - 465s 3s/step - loss: 0.9063 - acc: 0.6156 - val_loss: 1.3020 - val_acc: 0.2672
# Epoch 3/10
# 172/172 [==============================] - 464s 3s/step - loss: 1.1125 - acc: 0.4575 - val_loss: 1.0171 - val_acc: 0.4966
# Epoch 4/10
# 172/172 [==============================] - 463s 3s/step - loss: 0.8863 - acc: 0.5802 - val_loss: 0.8016 - val_acc: 0.6367
# Epoch 5/10
# 172/172 [==============================] - 463s 3s/step - loss: 0.8230 - acc: 0.6277 - val_loss: 0.7709 - val_acc: 0.6589
# Epoch 6/10
# 172/172 [==============================] - 459s 3s/step - loss: 0.7704 - acc: 0.6618 - val_loss: 0.7064 - val_acc: 0.6899
# Epoch 7/10
# 172/172 [==============================] - 459s 3s/step - loss: 0.7405 - acc: 0.6849 - val_loss: 0.7075 - val_acc: 0.6930
# Epoch 8/10
# 172/172 [==============================] - 459s 3s/step - loss: 0.6666 - acc: 0.7100 - val_loss: 0.6690 - val_acc: 0.7013
# Epoch 9/10
# 172/172 [==============================] - 457s 3s/step - loss: 0.7253 - acc: 0.6886 - val_loss: 0.7965 - val_acc: 0.6274
# Epoch 10/10
# 172/172 [==============================] - 455s 3s/step - loss: 0.7562 - acc: 0.6675 - val_loss: 0.8397 - val_acc: 0.6052

# %%
plot_graphs(history)

# %%
# definirea modelului-------------128-----128-------------
lstm_model = Sequential()
lstm_model.add(embedding_layer)
lstm_model.add(LSTM(128, return_sequences = True))
lstm_model.add(LSTM(128))
lstm_model.add(Dense(3, activation = 'softmax'))

lstm_model.compile(optimizer='rmsprop',
                   loss='categorical_crossentropy',
                   metrics=['acc'])
history = lstm_model.fit(x_train, 
                         y_train,
                         epochs=10,
                         batch_size=64,
                         validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 256s 1s/step - loss: 0.8563 - acc: 0.6153 - val_loss: 0.8190 - val_acc: 0.6398
# Epoch 2/10
# 172/172 [==============================] - 252s 1s/step - loss: 0.7733 - acc: 0.6672 - val_loss: 0.7798 - val_acc: 0.6543
# Epoch 3/10
# 172/172 [==============================] - 252s 1s/step - loss: 0.7278 - acc: 0.6886 - val_loss: 0.7080 - val_acc: 0.6915
# Epoch 4/10
# 172/172 [==============================] - 252s 1s/step - loss: 0.6912 - acc: 0.7005 - val_loss: 0.8762 - val_acc: 0.6320
# Epoch 5/10
# 172/172 [==============================] - 251s 1s/step - loss: 0.6731 - acc: 0.7064 - val_loss: 0.8068 - val_acc: 0.6537
# Epoch 5/10
# 172/172 [==============================] - 1386s 8s/step - loss: 0.6569 - acc: 0.7099 - val_loss: 0.7899 - val_acc: 0.6444
# Epoch 6/10
# 172/172 [==============================] - 1405s 8s/step - loss: 0.6293 - acc: 0.7272 - val_loss: 0.7305 - val_acc: 0.6698
# Epoch 7/10
# 172/172 [==============================] - 1389s 8s/step - loss: 0.7606 - acc: 0.6651 - val_loss: 0.7242 - val_acc: 0.7054
# Epoch 8/10
# 172/172 [==============================] - 1364s 8s/step - loss: 0.6630 - acc: 0.7208 - val_loss: 0.7017 - val_acc: 0.6853
# Epoch 9/10
# 172/172 [==============================] - 1347s 8s/step - loss: 0.6257 - acc: 0.7302 - val_loss: 0.6632 - val_acc: 0.7132
# Epoch 10/10
# 172/172 [==============================] - 1344s 8s/step - loss: 0.5865 - acc: 0.7480 - val_loss: 0.7536 - val_acc: 0.6868

# %%
plot_graphs(history)

# %%
# definirea modelului ------------------512------------------
gru_model = Sequential()
gru_model.add(embedding_layer)
gru_model.add(GRU(512))
gru_model.add(Dense(3, activation = 'softmax'))

gru_model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['acc'])
history = gru_model.fit(x_train,
                        y_train,
                        epochs=10,
                        batch_size=64,
                        validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 390s 2s/step - loss: 1.1337 - acc: 0.4450 - val_loss: 0.9810 - val_acc: 0.4388
# Epoch 2/10
# 172/172 [==============================] - 398s 2s/step - loss: 0.8526 - acc: 0.5959 - val_loss: 0.8288 - val_acc: 0.6202
# Epoch 3/10
# 172/172 [==============================] - 402s 2s/step - loss: 0.7712 - acc: 0.6521 - val_loss: 0.7364 - val_acc: 0.6765
# Epoch 4/10
# 172/172 [==============================] - 403s 2s/step - loss: 0.7263 - acc: 0.6803 - val_loss: 0.7198 - val_acc: 0.6775
# Epoch 5/10
# 172/172 [==============================] - 404s 2s/step - loss: 0.6946 - acc: 0.7004 - val_loss: 0.7302 - val_acc: 0.6687
# Epoch 6/10
# 172/172 [==============================] - 404s 2s/step - loss: 0.7636 - acc: 0.6885 - val_loss: 0.7289 - val_acc: 0.6879
# Epoch 7/10
# 172/172 [==============================] - 406s 2s/step - loss: 0.6616 - acc: 0.7133 - val_loss: 0.6828 - val_acc: 0.7028
# Epoch 8/10
# 172/172 [==============================] - 405s 2s/step - loss: 0.6452 - acc: 0.7173 - val_loss: 0.7010 - val_acc: 0.6894
# Epoch 9/10
# 172/172 [==============================] - 405s 2s/step - loss: 0.6281 - acc: 0.7304 - val_loss: 0.6980 - val_acc: 0.6904
# Epoch 10/10
# 172/172 [==============================] - 404s 2s/step - loss: 0.6114 - acc: 0.7344 - val_loss: 0.7063 - val_acc: 0.6858

# %%
plot_graphs(history)

# %%
# definirea modelului ------------------256-------128-----------
gru_model = Sequential()
gru_model.add(embedding_layer)
gru_model.add(GRU(256, return_sequences = True))
gru_model.add(GRU(128))
gru_model.add(Dense(3, activation = 'softmax'))

gru_model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['acc'])
history = gru_model.fit(x_train,
                        y_train,
                        epochs=10,
                        batch_size=64,
                        validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 308s 2s/step - loss: 0.9054 - acc: 0.5819 - val_loss: 0.7730 - val_acc: 0.6506
# Epoch 2/10
# 172/172 [==============================] - 302s 2s/step - loss: 0.7511 - acc: 0.6701 - val_loss: 0.7488 - val_acc: 0.6760
# Epoch 3/10
# 172/172 [==============================] - 302s 2s/step - loss: 0.6945 - acc: 0.6986 - val_loss: 0.9040 - val_acc: 0.6517
# Epoch 4/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.6652 - acc: 0.7101 - val_loss: 0.6913 - val_acc: 0.6946
# Epoch 5/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.6272 - acc: 0.7330 - val_loss: 0.7276 - val_acc: 0.6589
# Epoch 6/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.5999 - acc: 0.7425 - val_loss: 0.8520 - val_acc: 0.6258
# Epoch 7/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.5712 - acc: 0.7539 - val_loss: 0.6920 - val_acc: 0.6956
# Epoch 8/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.5487 - acc: 0.7672 - val_loss: 0.7599 - val_acc: 0.6817
# Epoch 9/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.5216 - acc: 0.7799 - val_loss: 0.6983 - val_acc: 0.7261
# Epoch 10/10
# 172/172 [==============================] - 301s 2s/step - loss: 0.4943 - acc: 0.7925 - val_loss: 0.6638 - val_acc: 0.7106

# %%
plot_graphs(history)

# %%
gru_model.evaluate(x_test, y_test)
# Out:
# 101/101 [==============================] - 41s 408ms/step - loss: 0.6877 - acc: 0.7054
# [0.6877079010009766, 0.7054263353347778]

# %%
pred=gru_model.predict(x_test)
pred=np.argmax(pred, axis=1)
ytest=np.argmax(y_test, axis=1)
# reduce to 1d array
print(classification_report(pred, ytest, target_names=['neg', 'n', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.78      0.69      0.73      1225
#            n       0.59      0.67      0.63       957
#          pos       0.75      0.75      0.75      1043
#
#     accuracy                           0.71      3225
#    macro avg       0.71      0.71      0.70      3225
# weighted avg       0.71      0.71      0.71      3225

# %% [markdown]
# ### Convnet 1D

# %%
# definirea modelului---------8------------------
convnet_model = Sequential()
convnet_model.add(embedding_layer)
convnet_model.add(Conv1D(8, 7, activation='relu'))
convnet_model.add(MaxPooling1D(5))
convnet_model.add(Conv1D(8, 7, activation='relu'))
convnet_model.add(GlobalMaxPooling1D())
convnet_model.add(Dense(3, activation='softmax'))

convnet_model.compile(optimizer=RMSprop(learning_rate=1e-4), 
                      loss='categorical_crossentropy', 
                      metrics=['acc'])
history = convnet_model.fit(x_train, 
                            y_train,
                            epochs=10,
                            batch_size=64,
                            validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 40s 232ms/step - loss: 1.0627 - acc: 0.3976 - val_loss: 1.0545 - val_acc: 0.4331
# Epoch 2/10
# 172/172 [==============================] - 37s 216ms/step - loss: 1.0424 - acc: 0.4683 - val_loss: 1.0404 - val_acc: 0.4863
# Epoch 3/10
# 172/172 [==============================] - 38s 219ms/step - loss: 1.0267 - acc: 0.5101 - val_loss: 1.0284 - val_acc: 0.5142
# Epoch 4/10
# 172/172 [==============================] - 42s 246ms/step - loss: 1.0123 - acc: 0.5340 - val_loss: 1.0164 - val_acc: 0.5204
# Epoch 5/10
# 172/172 [==============================] - 39s 228ms/step - loss: 0.9977 - acc: 0.5464 - val_loss: 1.0028 - val_acc: 0.5339
# Epoch 6/10
# 172/172 [==============================] - 39s 228ms/step - loss: 0.9825 - acc: 0.5509 - val_loss: 0.9884 - val_acc: 0.5370
# Epoch 7/10
# 172/172 [==============================] - 38s 223ms/step - loss: 0.9666 - acc: 0.5553 - val_loss: 0.9736 - val_acc: 0.5395
# Epoch 8/10
# 172/172 [==============================] - 39s 228ms/step - loss: 0.9504 - acc: 0.5604 - val_loss: 0.9590 - val_acc: 0.5483
# Epoch 9/10
# 172/172 [==============================] - 40s 231ms/step - loss: 0.9346 - acc: 0.5665 - val_loss: 0.9458 - val_acc: 0.5525
# Epoch 10/10
# 172/172 [==============================] - 40s 233ms/step - loss: 0.9193 - acc: 0.5980 - val_loss: 0.9323 - val_acc: 0.6196

# %%
plot_graphs(history)

# %%
# definirea modelului---------16------------------
convnet_model = Sequential()
convnet_model.add(embedding_layer)
convnet_model.add(Conv1D(16, 7, activation='relu'))
convnet_model.add(MaxPooling1D(5))
convnet_model.add(Conv1D(16, 7, activation='relu'))
convnet_model.add(GlobalMaxPooling1D())
convnet_model.add(Dense(3, activation='softmax'))

convnet_model.compile(optimizer=RMSprop(learning_rate=1e-4), 
                      loss='categorical_crossentropy', 
                      metrics=['acc'])
history = convnet_model.fit(x_train, 
                            y_train,
                            epochs=10,
                            batch_size=64,
                            validation_split=0.15)
# Out:
# Epoch 1/10
# 172/172 [==============================] -
ation='relu'))
convnet_model.add(MaxPooling1D(5))
convnet_model.add(Conv1D(512, 7,kernel_regularizer=l2(0.001), activation='relu'))
convnet_model.add(MaxPooling1D(5))
convnet_model.add(Conv1D(64, 7, activation='relu'))
convnet_model.add(GlobalMaxPooling1D())
convnet_model.add(Dense(3, activation='softmax'))

convnet_model.compile(optimizer=RMSprop(learning_rate=1e-4), 
                      loss='categorical_crossentropy', 
                      metrics=['acc'])
history = convnet_model.fit(x_train, 
                            y_train,
                            epochs=15,
                            batch_size=64,
                            validation_split=0.15)
# Out:
# Epoch 1/15
# 172/172 [==============================] - 98s 568ms/step - loss: 1.6574 - acc: 0.5500 - val_loss: 1.4299 - val_acc: 0.5726
# Epoch 2/15
# 172/172 [==============================] - 97s 565ms/step - loss: 1.3057 - acc: 0.6158 - val_loss: 1.3349 - val_acc: 0.5984
# Epoch 3/15
# 172/172 [==============================] - 97s 567ms/step - loss: 1.1463 - acc: 0.6532 - val_loss: 1.1153 - val_acc: 0.6501
# Epoch 4/15
# 172/172 [==============================] - 97s 564ms/step - loss: 1.0465 - acc: 0.6774 - val_loss: 1.1415 - val_acc: 0.6357
# Epoch 5/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.9702 - acc: 0.7041 - val_loss: 1.0953 - val_acc: 0.6388
# Epoch 6/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.9147 - acc: 0.7198 - val_loss: 0.9804 - val_acc: 0.6801
# Epoch 7/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.8668 - acc: 0.7334 - val_loss: 0.9508 - val_acc: 0.6858
# Epoch 8/15
# 172/172 [==============================] - 97s 565ms/step - loss: 0.8241 - acc: 0.7497 - val_loss: 0.9801 - val_acc: 0.6594
# Epoch 9/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.7876 - acc: 0.7618 - val_loss: 0.9605 - val_acc: 0.6661
# Epoch 10/15
# 172/172 [==============================] - 97s 565ms/step - loss: 0.7471 - acc: 0.7819 - val_loss: 1.1856 - val_acc: 0.6599
# Epoch 11/15
# 172/172 [==============================] - 97s 565ms/step - loss: 0.7145 - acc: 0.7968 - val_loss: 0.9133 - val_acc: 0.6941
# Epoch 12/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.6801 - acc: 0.8139 - val_loss: 0.9186 - val_acc: 0.6992
# Epoch 13/15
# 172/172 [==============================] - 97s 565ms/step - loss: 0.6513 - acc: 0.8268 - val_loss: 0.9236 - val_acc: 0.6935
# Epoch 14/15
# 172/172 [==============================] - 97s 565ms/step - loss: 0.6196 - acc: 0.8386 - val_loss: 0.9155 - val_acc: 0.7039
# Epoch 15/15
# 172/172 [==============================] - 97s 566ms/step - loss: 0.5906 - acc: 0.8565 - val_loss: 1.1287 - val_acc: 0.6734

# %%
plot_graphs(history)

# %%
convnet_model.evaluate(x_test, y_test)
# Out:
# 101/101 [==============================] - 8s 82ms/step - loss: 1.1170 - acc: 0.6763
# [1.1169867515563965, 0.6762790679931641]

# %%
pred=convnet_model.predict(x_test)
pred=np.argmax(pred, axis=1)
ytest=np.argmax(y_test, axis=1)
# reduce to 1d array
print(classification_report(pred, ytest, target_names=['neg', 'n', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.53      0.79      0.63       726
#            n       0.55      0.75      0.63       794
#          pos       0.96      0.60      0.74      1705
#
#     accuracy                           0.68      3225
#    macro avg       0.68      0.71      0.67      3225
# weighted avg       0.76      0.68      0.69      3225
